# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from configs.config import Config
from configs.comparisonConfig import ComparisonConfig
from configs.testDataConfig import TestDataConfig
import tensorflow as tf
from services.createPortfolioWrap import createPortfolioWrap
from services.createHistogramAndComparison import createHistogram
from services.createHistogramAndComparison import createComparison

gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU is", "available" if gpu else "NOT AVAILABLE")

# %%
comparisonFlipped10 = createComparison(TestDataConfig.flippedConfig(),
                                     ComparisonConfig(Config.flippedDir, "10"),
                                     "longEntry10", "shortEntry10")

# %%
comparisonFlipped50 = createComparison(TestDataConfig.flippedConfig(),
                                       ComparisonConfig(Config.flippedDir, "50"),
                                       "longEntry50", "shortEntry50")

# %%
comparisonFlipped100 = createComparison(TestDataConfig.flippedConfig(),
                                       ComparisonConfig(Config.flippedDir, "100"),
                                       "longEntry100", "shortEntry100")

# %%
comparisonOriginal10 = createComparison(TestDataConfig.btcConfig(), #TestDataConfig.btcSplitConfig(),
                                        ComparisonConfig(Config.originalDir, "10"),
                                        "longEntry10", "shortEntry10")

# %%
comparisonOriginal50 = createComparison(TestDataConfig.btcConfig(),
                                        ComparisonConfig(Config.originalDir, "50"),
                                        "longEntry50", "shortEntry50")

# %%
comparisonOriginal100 = createComparison(TestDataConfig.btcConfig(),
                                        ComparisonConfig(Config.originalDir, "100"),
                                        "longEntry100", "shortEntry100")

# %%
comparisonEth10 = createComparison(TestDataConfig.ethConfig(),
                                        ComparisonConfig(Config.secondDir, "10"),
                                        "longEntry10", "shortEntry10")

# %%
comparisonEth50 = createComparison(TestDataConfig.ethConfig(),
                                   ComparisonConfig(Config.secondDir, "50"),
                                   "longEntry50", "shortEntry50")

# %%
comparisonEth100 = createComparison(TestDataConfig.ethConfig(),
                                   ComparisonConfig(Config.secondDir, "100"),
                                   "longEntry100", "shortEntry100")

# %%
createHistogram(comparisonFlipped10, Config.relativeFlippedDataPath, Config.tickerTrain, None)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
createHistogram(comparisonFlipped10, Config.relativeFlippedDataPath, Config.secondTicker, None)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
createHistogram(comparisonOriginal10, Config.relativeDownloadDataPath,Config.tickerTrain,  Config.testIndexStart)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
createHistogram(comparisonOriginal10, Config.relativeDownloadDataPath,Config.tickerTrain, None)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
comparisonOriginal10.shape
# Out:
# (13872, 44)

# %%
createHistogram(comparisonEth10, Config.relativeDownloadDataPath,Config.secondTicker, None)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
createHistogram(comparisonOriginal50, Config.relativeDownloadDataPath,Config.tickerTrain, None)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
createHistogram(comparisonFlipped50, Config.relativeFlippedDataPath, Config.tickerTrain, None)
# previosuly had 50 at .85, .75 and 10 at .65, .65
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
createHistogram(comparisonEth50, Config.relativeDownloadDataPath,Config.secondTicker, None)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
createHistogram(comparisonOriginal100, Config.relativeDownloadDataPath,Config.tickerTrain, None)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
createHistogram(comparisonFlipped100, Config.relativeFlippedDataPath, Config.tickerTrain, None)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
createHistogram(comparisonEth100, Config.relativeDownloadDataPath,Config.secondTicker, None)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# cant find a best for 10
#best for 100 looks to be .9 and .45
#for 50 looks to be .75 .6

# %%
comparisonCnyUsd50 = createComparison(TestDataConfig.symbolConfig("C:CNYUSD"),
                                       ComparisonConfig(Config.otherDir, "50", "C:CNYUSD"),
                                       "longEntry50", "shortEntry50")
# Out:
# PATH IS /Users/user/PycharmProjects/vectorBtTry/3_make_model/rnn/2_split_train_test_features_targets/checkpoints/other/3_2_all_features_C:CNYUSD_2017-2023.h5
#  in fetchOrCreateSaveData
#  creating data at checkpoints/comparison/other/4_1_comparison_C:CNYUSD_period_50_2017-2023.h5
# model path is models/3_3_model_longEntry50
#  USING EXISTING
# model path is models/3_3_model_shortEntry50
#  USING EXISTING
# ...
# 893/893 [==============================] - 36s 40ms/step

# %%
comparisonCnyUsd50
# Out:
#                            predictedLongEntry  predictedShortEntry  \
# Open time
# 2017-02-07 11:00:00+00:00            0.992307             0.001773
# 2017-02-07 12:00:00+00:00            0.988856             0.002576
# 2017-02-07 13:00:00+00:00            0.979017             0.001801
# 2017-02-07 14:00:00+00:00            0.985874             0.001718
# 2017-02-07 15:00:00+00:00            0.982780             0.001696
# ...                                       ...                  ...
# 2022-12-30 12:00:00+00:00            0.997251             0.000495
# 2022-12-30 13:00:00+00:00            0.996881             0.000593
# 2022-12-30 14:00:00+00:00            0.997792             0.000502
# 2022-12-30 15:00:00+00:00            0.998177             0.000506
# 2022-12-30 16:00:00+00:00            0.997044             0.000837
#
#                            actualLongEntry  actualShortEntry  \
# Open time
# 2017-02-07 11:00:00+00:00                0                 0
# ...

# %%
createHistogram(comparisonCnyUsd50, Config.relativeSymbolDownloadDataPath("C:CNYUSD"),
                "C:CNYUSD", None)

# %%
comparisonXMR50 = createComparison(TestDataConfig.symbolConfig("X:XMRUSD"),
                                      ComparisonConfig(Config.otherDir, "50", "X:XMRUSD"),
                                      "longEntry50", "shortEntry50")

# %%
comparisonXMR10 = createComparison(TestDataConfig.symbolConfig("X:XMRUSD"),
                                   ComparisonConfig(Config.otherDir, "10", "X:XMRUSD"),
                                   "longEntry10", "shortEntry10")
# Out:
# [autoreload of services.ModelTester failed: Traceback (most recent call last):
#   File "/Users/user/opt/anaconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 261, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/user/opt/anaconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 459, in superreload
#     module = reload(module)
#   File "/Users/user/opt/anaconda3/lib/python3.9/importlib/__init__.py", line 168, in reload
#     raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
# ModuleNotFoundError: spec not found for the module 'services.ModelTester'
# ]
# PATH IS /Users/user/PycharmProjects/vectorBtTry/3_make_model/rnn/2_split_train_test_features_targets/checkpoints/other/3_2_all_features_X:XMRUSD_2017-2023.h5
#  in fetchOrCreateSaveData
#  creating data at checkpoints/comparison/other/4_1_comparison_X:XMRUSD_period_10_2017-2023.h5
# model path is models/3_3_model_longEntry10
# ...

# %%
createHistogram(comparisonXMR50, Config.relativeSymbolDownloadDataPath("X:XMRUSD"),
                "X:XMRUSD", None)

# %%
pf50CnyWrap = createPortfolioWrap(Config.otherDir, Config.relativeSymbolDownloadDataPath('C:CNYUSD'),
                                      'C:CNYUSD', 50, .75, .6)
pf50Cny = pf50CnyWrap.portfolio
pf50Cny.stats()
# Out:
# Start                         2017-02-07 11:00:00+00:00
# End                           2022-12-30 16:00:00+00:00
# Period                                            28564
# Start Value                                     10000.0
# Min Value                                        9700.0
# Max Value                                  11014.732204
# End Value                                        9700.0
# Total Return [%]                                   -3.0
# Benchmark Return [%]                          -0.218753
# Total Time Exposure [%]                       49.100266
# Max Gross Exposure [%]                            100.0
# Max Drawdown [%]                              11.936125
# Max Drawdown Duration                           21509.0
# Total Orders                                          2
# Total Fees Paid                                     0.0
# Total Trades                                          1
# Win Rate [%]                                        0.0
# ...

# %%
pf50Cny.orders

# %%
comparisonDOGE50 = createComparison(TestDataConfig.symbolConfig("X:DOGEUSD"),
                                   ComparisonConfig(Config.otherDir, "50", "X:DOGEUSD"),
                                   "longEntry50", "shortEntry50")

# %%
createHistogram(comparisonDOGE50, Config.relativeSymbolDownloadDataPath("X:DOGEUSD"),
                "X:DOGEUSD", None)
