# %%
# https://machinelearningmastery.com/visualize-deep-learning-neural-network-model-keras/
from keras.models import Sequential
from keras.layers import Dense
from keras.utils.vis_utils import plot_model

# may need to install https://graphviz.gitlab.io/download/
# and pip install pydot`

# %%
from common.modelLoader import ModelLoader
longTargetKey = "longEntry50"

longRnn, longHistory = ModelLoader.loadModel(longTargetKey)

plot_model(longRnn, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# model path is /Users/user/PycharmProjects/vectorBtTry/4_test_model/models/3_3_model_longEntry50
#  Using Existing model
